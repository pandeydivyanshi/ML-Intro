# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# ## dealing with categorical data

# %% [markdown]
# ### a. countplot

# %%
df=pd.read_csv('tested.csv')
sb.countplot(x='Survived', data=df)
plt.show()

# %%
df=pd.read_csv('tested.csv')
sb.countplot(x='Pclass', data=df)
plt.show()

# %%
df=pd.read_csv('tested.csv')
sb.countplot(x='Sex', data=df)
plt.show()

# %%
df=pd.read_csv('tested.csv')
sb.countplot(x='SibSp', data=df)
plt.show()

# %%
df=pd.read_csv('tested.csv')
sb.countplot(x='Parch', data=df)
plt.show()

# %%
df=pd.read_csv('tested.csv')
sb.countplot(x='Embarked', data=df)
plt.show()

# %% [markdown]
# ## b. piechart

# %% [markdown]
# for percentage over viwe

# %%
df=pd.read_csv('tested.csv')
df['Survived'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %%
df=pd.read_csv('tested.csv')
df['Pclass'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %%
df=pd.read_csv('tested.csv')
df['Sex'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %%
df=pd.read_csv('tested.csv')
df['SibSp'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %%
df=pd.read_csv('tested.csv')
df['Parch'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %%
df=pd.read_csv('tested.csv')
df['Embarked'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Numerical data

# %% [markdown]
# ### a. Histogram

# %%
df=pd.read_csv('tested.csv')
plt.hist(df['Age'])
plt.show()

# %%
df=pd.read_csv('tested.csv')
plt.hist(df['Ticket'])
plt.show()

# %%
df=pd.read_csv('tested.csv')
plt.hist(df['Fare'])
plt.show()

# %% [markdown]
# ### b.distplot

# %%
df=pd.read_csv('tested.csv')
sb.histplot(df['Age'], kde=True)
plt.show()

# %%
df=pd.read_csv('tested.csv')
sb.histplot(df['Fare'], kde=True)
plt.show()

# %%
df=pd.read_csv('tested.csv')
sb.distplot(df['Fare'],kde=True)
plt.show()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_19476\2168842332.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['Fare'],kde=True)

# %% [markdown]
# ## BOXPLOT

# %%
df=pd.read_csv('tested.csv')
sb.boxplot(x=df['Age'])
plt.show()

# %%
df=pd.read_csv('tested.csv')
sb.boxplot(x=df['Ticket'])
plt.show()

# %%
df=pd.read_csv('tested.csv')
sb.boxplot(x=df['Fare'])
plt.show()

# %% [markdown]
# ## calculating statistical parameter

# %%
df['Age'].min()
df['Age'].max()
df['Age'].mean()
df['Age'].median()
